# %% [markdown]
# # Player Clustering Based on Profile and Physical Performance
#
# ### Students
# Matheus Grandinetti Barbosa Lima
#
# Pedro Henrique Baptista Fernandes
#
# Marcelo Augusto Mrad Marteleto
#
# Pedro Henrique Egito

# %%
from clustering import Clustering

# %% [markdown]
# ## Clustering analysis

# %%
clustering = Clustering()
df_player = clustering.create_playar_data()
df_player.head()
# Out:
#                                 playerId          team
# gameId shirtNumber isAwayorHome
# 12496  39          home            18603      Botafogo
#        29          away            17884  São Paulo FC
#        23          away            18102  São Paulo FC
#        11          away            17886  São Paulo FC
#        5           home             7365      Botafogo

# %%
game_id = "12844"
data = clustering.read_game_data(game_id)
frames = clustering.process_frames(data, df_player, game_id)
df_frames = clustering.metrics.compute_player_metrics(frames)
df_frames.head()
# Out:
#    playerId  max_acceleration  mean_acceleration  mean_distance_per_frame  \
# 0      2364        129.922676           0.001505                 0.081481
# 1      2530        135.373273           0.000185                 0.072750
# 2      3658        458.610562           0.000148                 0.067783
# 3     13829        143.405161           0.000250                 0.047585
# 4     14817        137.111517           0.001251                 0.078618
#
#    max_distance_in_a_frame  total_distance
# 0                 1.858200     1949.754332
# 1                30.547330    11513.918556
# 2                12.963758     7273.423246
# 3                78.891212     8668.428974
# 4                 3.066266     1835.257765

# %%
x_scaled = clustering.pairplot_metrics(df_frames)
# Out:
# /home/mfreya/Faculdade/8periodo/futebol/Projeto-Final-Futebol/venv/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
clustering.plot_player_clusters(df_frames, x_scaled)

# %% [markdown]
# ## Injuries analysis

# %%
from injuries import Injuries
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (9, 4)

# %%
injuries = Injuries()
injuries.init_aux_columns()
injuries.init_metrics()
metrics = injuries.generate_metrics()
# Out:
#                          risk_share  availability_idx  injury_entropy  \
# Club         season_year
# Amazonas Fc  2010               1.0          0.416438        0.000000
# Ec Juventude 2012               1.0          0.945205        0.000000
# Cruzeiro Ec  2018               1.0          0.976712        1.584963
#              2019               1.0          0.889954        2.128085
# Cuiaba Ec Mt 2022               1.0          0.836530        1.584963
#              2023               1.0          0.305753        1.921928
# Ec Bahia     2012               1.0          0.931507        0.000000
#              2014               1.0          0.972603        0.000000
#              2015               1.0          0.845662        1.921928
#              2016               1.0          0.975342        0.000000
#
#                           n_injuries
# Club         season_year
# Amazonas Fc  2010                  1
# Ec Juventude 2012                  1
# Cruzeiro Ec  2018                  3
#              2019                  7
# Cuiaba Ec Mt 2022                  3
#              2023                  5
# Ec Bahia     2012                  1
#              2014                  1
#              2015                  5
#              2016                  1

# %%
injuries.init_references(metrics)
injuries.plot_team_total_injuries()
# Out:
# /home/mfreya/Faculdade/8periodo/futebol/Projeto-Final-Futebol/injuries.py:164: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top15.index, x=top15.values, palette="crest")

# %%
injuries.plot_anual_injuries_evolution()

# %%
injuries.high_risk_players()
# Out:
# /home/mfreya/Faculdade/8periodo/futebol/Projeto-Final-Futebol/injuries.py:188: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=risk_2024.index, y=risk_2024.values, palette="rocket_r")

# %%
injuries.plot_availability_per_season()

# %%
injuries.plot_top_10_injured_teams()

# %%
injuries.plot_anual_injury_evolution_per_team()
